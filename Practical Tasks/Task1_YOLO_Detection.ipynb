# %%
pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/e7/66/3c3fd38fc2350b5c376bcfc44fa682dc4282d39856d3dfc54679a8bcec7e/ultralytics-8.3.39-py3-none-any.whl.metadata
#   Using cached ultralytics-8.3.39-py3-none-any.whl.metadata (35 kB)
# ...
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/ec/6c/fab8113424af5049f85717e8e527ca3773299a3c6b02506e66436e19874f/opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/0d/4a/e51420d46cfc90562e85af2fee912237c662ab31140ab179e49bd69401d6/torch-2.5.1-cp311-cp311-win_amd64.whl.metadata
#   Using cached torch-2.5.1-cp311-cp311-win_amd64.whl.metadata (28 kB)
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

#Image Detection
results=model(source=r"C:\Users\asd432\Desktop\Task1_Image_Detection.jpg",show=True,conf=0.4,save=True)
#video Detection
results=model(source=r"C:\Users\asd432\Desktop\Task1_Video_Detection.MP4",show=True,conf=0.4,save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/411) C:\Users\asd432\Desktop\videoo.MP4: 384x640 14 persons, 79.5ms
# video 1/1 (frame 2/411) C:\Users\asd432\Desktop\videoo.MP4: 384x640 14 persons, 119.1ms
# video 1/1 (frame 3/411) C:\Users\asd432\Desktop\videoo.MP4: 384x640 13 persons, 84.1ms
# video 1/1 (frame 4/411) C:\Users\asd432\Desktop\videoo.MP4: 384x640 14 persons, 77.9ms
# ...
