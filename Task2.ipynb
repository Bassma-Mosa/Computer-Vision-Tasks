# %%
from sklearn import datasets
# Load dataset
data = datasets.load_breast_cancer()
X = data.data
y = data.target

# %%
from sklearn.model_selection import train_test_split
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow import keras
from tensorflow.keras import layers

# Load dataset
data = datasets.load_breast_cancer()
X = data.data
y = data.target

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Create the ANN model
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Use 'softmax' for multi-class problems
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=10, validation_split=0.3)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy:.4f}')

# Predictions
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# Evaluation metrics
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Epoch 1/100
# D:\program\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8475 - loss: 0.4476 - val_accuracy: 0.9583 - val_loss: 0.1754
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9683 - loss: 0.1281 - val_accuracy: 0.9500 - val_loss: 0.1266
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9772 - loss: 0.0862 - val_accuracy: 0.9500 - val_loss: 0.1138
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9683 - loss: 0.0885 - val_accuracy: 0.9583 - val_loss: 0.1025
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0390 - val_accuracy: 0.9667 - val_loss: 0.1050
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9873 - loss: 0.0377 - val_accuracy: 0.9667 - val_loss: 0.0931
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9910 - loss: 0.0397 - val_accuracy: 0.9750 - val_loss: 0.0968
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0323 - val_accuracy: 0.9750 - val_loss: 0.0962
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0287 - val_accuracy: 0.9750 - val_loss: 0.0916
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9964 - loss: 0.0147 - val_accuracy: 0.9750 - val_loss: 0.0985
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9667 - val_loss: 0.0968
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0109 - val_accuracy: 0.9750 - val_loss: 0.0926
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.9750 - val_loss: 0.0948
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9750 - val_loss: 0.1003
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9667 - val_loss: 0.1055
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9667 - val_loss: 0.1092
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9583 - val_loss: 0.1069
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9583 - val_loss: 0.1087
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9667 - val_loss: 0.1081
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9583 - val_loss: 0.1151
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9583 - val_loss: 0.1124
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9583 - val_loss: 0.1176
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9583 - val_loss: 0.1155
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9583 - val_loss: 0.1164
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9583 - val_loss: 0.1211
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9583 - val_loss: 0.1228
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.7677e-04 - val_accuracy: 0.9583 - val_loss: 0.1224
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.1369e-04 - val_accuracy: 0.9583 - val_loss: 0.1261
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 9.4428e-04 - val_accuracy: 0.9583 - val_loss: 0.1267
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.8028e-04 - val_accuracy: 0.9583 - val_loss: 0.1274
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.8511e-04 - val_accuracy: 0.9583 - val_loss: 0.1298
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.0236e-04 - val_accuracy: 0.9583 - val_loss: 0.1294
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.6476e-04 - val_accuracy: 0.9583 - val_loss: 0.1321
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.2042e-04 - val_accuracy: 0.9583 - val_loss: 0.1333
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.2816e-04 - val_accuracy: 0.9583 - val_loss: 0.1347
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.6219e-04 - val_accuracy: 0.9583 - val_loss: 0.1354
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.1649e-04 - val_accuracy: 0.9583 - val_loss: 0.1365
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.6519e-04 - val_accuracy: 0.9583 - val_loss: 0.1374
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.4616e-04 - val_accuracy: 0.9583 - val_loss: 0.1386
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.0524e-04 - val_accuracy: 0.9583 - val_loss: 0.1410
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.2376e-04 - val_accuracy: 0.9583 - val_loss: 0.1407
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.9832e-04 - val_accuracy: 0.9583 - val_loss: 0.1433
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.4798e-04 - val_accuracy: 0.9583 - val_loss: 0.1433
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.7491e-04 - val_accuracy: 0.9583 - val_loss: 0.1452
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.6738e-04 - val_accuracy: 0.9583 - val_loss: 0.1463
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.0462e-04 - val_accuracy: 0.9583 - val_loss: 0.1468
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.6563e-04 - val_accuracy: 0.9583 - val_loss: 0.1490
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.0319e-04 - val_accuracy: 0.9583 - val_loss: 0.1478
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.1188e-04 - val_accuracy: 0.9583 - val_loss: 0.1495
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.6243e-04 - val_accuracy: 0.9583 - val_loss: 0.1504
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.8764e-04 - val_accuracy: 0.9583 - val_loss: 0.1514
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.3132e-04 - val_accuracy: 0.9583 - val_loss: 0.1523
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 2.3190e-04 - val_accuracy: 0.9583 - val_loss: 0.1536
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.4171e-04 - val_accuracy: 0.9583 - val_loss: 0.1559
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1190e-04 - val_accuracy: 0.9583 - val_loss: 0.1538
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4607e-04 - val_accuracy: 0.9583 - val_loss: 0.1569
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5730e-04 - val_accuracy: 0.9583 - val_loss: 0.1562
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.5424e-04 - val_accuracy: 0.9583 - val_loss: 0.1565
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 2.2221e-04 - val_accuracy: 0.9583 - val_loss: 0.1577
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1142e-04 - val_accuracy: 0.9583 - val_loss: 0.1609
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.4847e-04 - val_accuracy: 0.9583 - val_loss: 0.1591
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.3213e-04 - val_accuracy: 0.9583 - val_loss: 0.1612
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0146e-04 - val_accuracy: 0.9583 - val_loss: 0.1620
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1220e-04 - val_accuracy: 0.9583 - val_loss: 0.1604
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0821e-04 - val_accuracy: 0.9583 - val_loss: 0.1633
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.4583e-04 - val_accuracy: 0.9583 - val_loss: 0.1652
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.0013e-04 - val_accuracy: 0.9583 - val_loss: 0.1624
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.1698e-04 - val_accuracy: 0.9583 - val_loss: 0.1643
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.0189e-04 - val_accuracy: 0.9583 - val_loss: 0.1678
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.0134e-05 - val_accuracy: 0.9583 - val_loss: 0.1651
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.0234e-04 - val_accuracy: 0.9583 - val_loss: 0.1658
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.8547e-05 - val_accuracy: 0.9583 - val_loss: 0.1673
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.6958e-05 - val_accuracy: 0.9583 - val_loss: 0.1677
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 7.7408e-05 - val_accuracy: 0.9583 - val_loss: 0.1695
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.0211e-04 - val_accuracy: 0.9583 - val_loss: 0.1705
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.4389e-05 - val_accuracy: 0.9583 - val_loss: 0.1718
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.9318e-05 - val_accuracy: 0.9583 - val_loss: 0.1693
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 8.3588e-05 - val_accuracy: 0.9583 - val_loss: 0.1711
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 9.1646e-05 - val_accuracy: 0.9583 - val_loss: 0.1718
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 8.3904e-05 - val_accuracy: 0.9583 - val_loss: 0.1726
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.1440e-05 - val_accuracy: 0.9583 - val_loss: 0.1723
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.6355e-05 - val_accuracy: 0.9583 - val_loss: 0.1739
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.7428e-05 - val_accuracy: 0.9583 - val_loss: 0.1766
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.7786e-05 - val_accuracy: 0.9583 - val_loss: 0.1747
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.0318e-05 - val_accuracy: 0.9583 - val_loss: 0.1755
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.7026e-05 - val_accuracy: 0.9583 - val_loss: 0.1761
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.5845e-05 - val_accuracy: 0.9667 - val_loss: 0.1763
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 5.5404e-05 - val_accuracy: 0.9583 - val_loss: 0.1780
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.8179e-05 - val_accuracy: 0.9583 - val_loss: 0.1783
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 7.2745e-05 - val_accuracy: 0.9667 - val_loss: 0.1793
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.4221e-05 - val_accuracy: 0.9667 - val_loss: 0.1778
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.1243e-05 - val_accuracy: 0.9667 - val_loss: 0.1796
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.9833e-05 - val_accuracy: 0.9583 - val_loss: 0.1808
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.6872e-05 - val_accuracy: 0.9667 - val_loss: 0.1805
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 6.7585e-05 - val_accuracy: 0.9667 - val_loss: 0.1818
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.5693e-05 - val_accuracy: 0.9667 - val_loss: 0.1816
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 4.9875e-05 - val_accuracy: 0.9583 - val_loss: 0.1837
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 3.2903e-05 - val_accuracy: 0.9667 - val_loss: 0.1851
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.6407e-05 - val_accuracy: 0.9667 - val_loss: 0.1835
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 3.4409e-05 - val_accuracy: 0.9667 - val_loss: 0.1842
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9813 - loss: 0.1767
# Accuracy: 0.9825
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# [[ 60   3]
#  [  0 108]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.98        63
#            1       0.97      1.00      0.99       108
#
#     accuracy                           0.98       171
#    macro avg       0.99      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

# Load dataset
data = datasets.load_breast_cancer()
X = data.data
y = data.target

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Create KNN model
k = 6  # You can experiment with different values of k
knn_model = KNeighborsClassifier(n_neighbors=k)
knn_model.fit(X_train, y_train)

# Make predictions
y_pred = knn_model.predict(X_test)

# Evaluate the model
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 59   4]
#  [  3 105]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94        63
#            1       0.96      0.97      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

# Load data
data = datasets.load_breast_cancer()
X = data.data
y = data.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Create SVM model
svm_model = SVC(kernel='rbf',C='0.1',Gamma.001')
svm_model.fit(X_train, y_train)

# Predictions
y_pred = svm_model.predict(X_test)

# Evaluation
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
#   Cell In[13], line 21
#     svm_model = SVC(kernel='rbf',C='0.1',Gamma.001')
#                                                   ^
# SyntaxError: unterminated string literal (detected at line 21)
